# %%
import os
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

os.chdir("/Users/zhongyuanchen/EDA_Customer_Segmentation")
df = pd.read_csv("marketing.csv",delimiter=';')

# %%
df.head().transpose()
# Out:
#                               0           1           2           3  \
# ID                         5524        2174        4141        6182
# Year_Birth                 1957        1954        1965        1984
# Education            Graduation  Graduation  Graduation  Graduation
# Marital_Status           Single      Single    Together    Together
# Income                  58138.0     46344.0     71613.0     26646.0
# Kidhome                       0           1           0           1
# Teenhome                      0           1           0           0
# Dt_Customer          2012-09-04  2014-03-08  2013-08-21  2014-02-10
# Recency                      58          38          26          26
# MntWines                    635          11         426          11
# MntFruits                    88           1          49           4
# MntMeatProducts             546           6         127          20
# MntFishProducts             172           2         111          10
# MntSweetProducts             88           1          21           3
# MntGoldProds                 88           6          42           5
# NumDealsPurchases             3           2           1           2
# NumWebPurchases               8           1           8           2
# NumCatalogPurchases          10           1           2           0
# NumStorePurchases             4           2          10           4
# NumWebVisitsMonth             7           5           4           6
# AcceptedCmp3                  0           0           0           0
# AcceptedCmp4                  0           0           0           0
# AcceptedCmp5                  0           0           0           0
# AcceptedCmp1                  0           0           0           0
# AcceptedCmp2                  0           0           0           0
# Complain                      0           0           0           0
# Z_CostContact                 3           3           3           3
# Z_Revenue                    11          11          11          11
# Response                      1           0           0           0
#
#                               4
# ID                         5324
# Year_Birth                 1981
# Education                   PhD
# Marital_Status          Married
# Income                  58293.0
# Kidhome                       1
# Teenhome                      0
# Dt_Customer          2014-01-19
# Recency                      94
# MntWines                    173
# MntFruits                    43
# MntMeatProducts             118
# MntFishProducts              46
# MntSweetProducts             27
# MntGoldProds                 15
# NumDealsPurchases             5
# NumWebPurchases               5
# NumCatalogPurchases           3
# NumStorePurchases             6
# NumWebVisitsMonth             5
# AcceptedCmp3                  0
# AcceptedCmp4                  0
# AcceptedCmp5                  0
# AcceptedCmp1                  0
# AcceptedCmp2                  0
# Complain                      0
# Z_CostContact                 3
# Z_Revenue                    11
# Response                      0

# %% [markdown]
# ## DATA Cleaning

# %%
# Drop null values
num_missing = df.apply( lambda x: any(x.isna()) ,axis=1).sum()
print(f"Number of rows with missing values: {num_missing}") 

# Only 24 columns with missing values, we can apply dropna function to the dataframe
df=df.dropna()

# Drop columns with only one value for all rows
nunique = df.nunique()
cols_to_drop = nunique[nunique == 1].index
df.drop(cols_to_drop, axis=1,inplace=True)

# Drop the ID column as it provides no information for analysis
df.drop("ID",axis=1,inplace=True)

# Drop outliers with Z-Score greater than 5, here we make an exception for #complains
numeric_df = df.select_dtypes(np.number).drop("Complain",axis=1)
filt = abs( stats.zscore(numeric_df,axis=0) )<=5
filt = filt.all(axis=1)
df = df.loc[ filt ]

# Drop columns with only one value for all rows after data cleaning
nunique = df.nunique()
cols_to_drop = nunique[nunique == 1].index
df.drop(cols_to_drop, axis=1,inplace=True)

print("The data is now clean")
# Out:
# Number of rows with missing values: 24
# The data is now clean

# %% [markdown]
# ## Data Transformation

# %%
# Numericalize education as years of higher education
df["Years of Higher Education"]=df["Education"].replace( {"Basic":0,"Master":6,"PhD":10,"Graduation":4,"2n Cycle":5} )

# Add age as feature
df["Age"] = 2015-df["Year_Birth"]
df=df.drop("Year_Birth",axis=1)

# Transform and numericalize Marital_Status as single/0 or Together/1
df["Marital_Status"].replace( ['Divorced', 'Widow', 'Alone','Absurd', 'YOLO'],'Single', inplace=True )
df["Numerical_Marital_Status"]=df["Marital_Status"].replace({"Single":0,"Together":1,"Married":1})

# Number of dependencies
df["Num_Dependencies"] = df["Kidhome"]+df["Teenhome"]

# Change the name of columns to be more decriptive
df.columns = [ colname.replace("Mnt","Spend on ") for colname in df.columns]

# Create a feature for total spend
df["Total Spend"] =  df[ [ 'Spend on Wines', 'Spend on Fruits',
       'Spend on MeatProducts', 'Spend on FishProducts',
       'Spend on SweetProducts', 'Spend on GoldProds' ] ].sum(axis=1)

# Drop the categorical columns
to_drop = ["Marital_Status", "Dt_Customer","Education"]
df.drop(to_drop, axis=1,inplace=True)



print(df.dtypes)
print("\nData frame is now all numerical")
# Out:
# Income                       float64
# Kidhome                        int64
# Teenhome                       int64
# Recency                        int64
# Spend on Wines                 int64
# Spend on Fruits                int64
# Spend on MeatProducts          int64
# Spend on FishProducts          int64
# Spend on SweetProducts         int64
# Spend on GoldProds             int64
# NumDealsPurchases              int64
# NumWebPurchases                int64
# NumCatalogPurchases            int64
# NumStorePurchases              int64
# NumWebVisitsMonth              int64
# AcceptedCmp3                   int64
# AcceptedCmp4                   int64
# AcceptedCmp5                   int64
# AcceptedCmp1                   int64
# Complain                       int64
# Response                       int64
# Years of Higher Education      int64
# Age                            int64
# Numerical_Marital_Status       int64
# Num_Dependencies               int64
# Total Spend                    int64
# dtype: object
#
# Data frame is now all numerical

# %% [markdown]
# ## Correlation Analysis

# %%
# Calculate the correlation matrix and visualized it as heat map

corr=df.corr()
plt.figure(figsize=(20,20)) 
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#     The visualization above might have too many columns and rows to look at.
#     Bellow, a correlation data frame that is sorted by absolute value of correlation is shown for ease of analysis

# %%
# Sort the correlation dataframe for ease of analysis
def zip_sort(x):
    sorted_ser = abs(x).sort_values(ascending=False)
    return pd.Series( zip( sorted_ser.index , x.loc[ sorted_ser.index ] ) )
def Sort_Correlated(corr):
    corr = corr.apply( zip_sort )
    return corr[1:].transpose()

sorted_corr = Sort_Correlated(corr)
sorted_corr
# Out:
#                                                                           1   \
# Income                                     (Total Spend, 0.8036047706566107)
# Kidhome                               (Num_Dependencies, 0.6869343678460531)
# Teenhome                              (Num_Dependencies, 0.6942523251305438)
# Recency                                      (Response, -0.2059129430826267)
# Spend on Wines                             (Total Spend, 0.9012299910082329)
# Spend on Fruits                            (Total Spend, 0.6268651768171082)
# Spend on MeatProducts                      (Total Spend, 0.8698198349481657)
# Spend on FishProducts                      (Total Spend, 0.6545070546321563)
# Spend on SweetProducts                     (Total Spend, 0.6256572064142801)
# Spend on GoldProds                         (Total Spend, 0.5419291068942486)
# NumDealsPurchases                     (Num_Dependencies, 0.4747688769305102)
# NumWebPurchases                         (Spend on Wines, 0.6046425651180026)
# NumCatalogPurchases                        (Total Spend, 0.8072170944805094)
# NumStorePurchases                          (Total Spend, 0.6887578283222773)
# NumWebVisitsMonth                               (Income, -0.663073017694985)
# AcceptedCmp3                                  (Response, 0.2525655527231903)
# AcceptedCmp4                             (Spend on Wines, 0.334021794461375)
# AcceptedCmp5                              (Total Spend, 0.45844665620785474)
# AcceptedCmp1                              (AcceptedCmp5, 0.3791308827828684)
# Complain                   (Years of Higher Education, -0.036937311893614...
# Response                                  (AcceptedCmp5, 0.2960695677965971)
# Years of Higher Education              (Spend on Wines, 0.19840546012563648)
# Age                                           (Teenhome, 0.3633449192913641)
# Numerical_Marital_Status                    (Response, -0.14473900312478813)
# Num_Dependencies                              (Teenhome, 0.6942523251305438)
# Total Spend                             (Spend on Wines, 0.9012299910082329)
#
#                                                                        2   \
# Income                                (Spend on Wines, 0.715882978719743)
# Kidhome                                (Total Spend, -0.5597274162141495)
# Teenhome                         (NumDealsPurchases, 0.42748557288524947)
# Recency                             (AcceptedCmp3, -0.033018462723336126)
# Spend on Wines                                (Income, 0.715882978719743)
# Spend on Fruits               (Spend on FishProducts, 0.5952201137018553)
# Spend on MeatProducts           (NumCatalogPurchases, 0.7121993140059071)
# Spend on FishProducts         (Spend on MeatProducts, 0.6106589664768644)
# Spend on SweetProducts        (Spend on FishProducts, 0.5876684962644724)
# Spend on GoldProds               (NumCatalogPurchases, 0.497571072352281)
# NumDealsPurchases                         (Teenhome, 0.42748557288524947)
# NumWebPurchases                         (Total Spend, 0.5733454703560453)
# NumCatalogPurchases           (Spend on MeatProducts, 0.7121993140059071)
# NumStorePurchases                            (Income, 0.6591315636506273)
# NumWebVisitsMonth            (Spend on MeatProducts, -0.5547268550162219)
# AcceptedCmp3                     (Spend on GoldProds, 0.1265155713027966)
# AcceptedCmp4                          (AcceptedCmp5, 0.28115694720522255)
# AcceptedCmp5                        (Spend on Wines, 0.45669398069185374)
# AcceptedCmp1                           (Total Spend, 0.37452471655492353)
# Complain                                   (Kidhome, 0.03659426552760407)
# Response                              (AcceptedCmp1, 0.26820739645293046)
# Years of Higher Education                    (Income, 0.1599403808327332)
# Age                                       (Kidhome, -0.24508889851204602)
# Numerical_Marital_Status   (Spend on MeatProducts, -0.036125996906753575)
# Num_Dependencies                            (Kidhome, 0.6869343678460531)
# Total Spend                   (Spend on MeatProducts, 0.8698198349481657)
#
#                                                                      3   \
# Income                        (NumCatalogPurchases, 0.7099019244424642)
# Kidhome                      (NumCatalogPurchases, -0.5347080518370962)
# Teenhome                                      (Age, 0.3633449192913641)
# Recency                      (NumWebVisitsMonth, -0.028191053540690594)
# Spend on Wines                 (NumCatalogPurchases, 0.694758477668525)
# Spend on Fruits             (Spend on MeatProducts, 0.5788076362387176)
# Spend on MeatProducts                      (Income, 0.7014182946177069)
# Spend on FishProducts             (Spend on Fruits, 0.5952201137018553)
# Spend on SweetProducts      (Spend on MeatProducts, 0.5777275796304928)
# Spend on GoldProds         (Spend on FishProducts, 0.43694370056210013)
# NumDealsPurchases               (NumWebVisitsMonth, 0.3536231285323409)
# NumWebPurchases                  (NumStorePurchases, 0.556876952381916)
# NumCatalogPurchases                        (Income, 0.7099019244424642)
# NumStorePurchases                  (Spend on Wines, 0.6483744015160556)
# NumWebVisitsMonth            (NumCatalogPurchases, -0.5489379907577792)
# AcceptedCmp3                 (NumCatalogPurchases, 0.12042835576530896)
# AcceptedCmp4                         (Total Spend, 0.22353767386182957)
# AcceptedCmp5                (Spend on MeatProducts, 0.3940207292369547)
# AcceptedCmp1                        (Spend on Wines, 0.336811748561612)
# Complain                        (Spend on Wines, -0.035677648585537215)
# Response                             (AcceptedCmp3, 0.2525655527231903)
# Years of Higher Education                     (Age, 0.1569529863927901)
# Age                                        (Income, 0.2141987490013356)
# Numerical_Marital_Status       (Num_Dependencies, 0.035318837883867034)
# Num_Dependencies            (Spend on MeatProducts, -0.520879657224567)
# Total Spend                   (NumCatalogPurchases, 0.8072170944805094)
#
#                                                                       4   \
# Income                       (Spend on MeatProducts, 0.7014182946177069)
# Kidhome                                    (Income, -0.5228484504749652)
# Teenhome                   (Spend on MeatProducts, -0.26288400669640993)
# Recency                      (NumCatalogPurchases, 0.027549048547353003)
# Spend on Wines                   (NumStorePurchases, 0.6483744015160556)
# Spend on Fruits             (Spend on SweetProducts, 0.5764631073736428)
# Spend on MeatProducts               (Spend on Wines, 0.6215812339841893)
# Spend on FishProducts       (Spend on SweetProducts, 0.5876684962644724)
# Spend on SweetProducts             (Spend on Fruits, 0.5764631073736428)
# Spend on GoldProds                         (Income, 0.41752450488608406)
# NumDealsPurchases                  (NumWebPurchases, 0.3149185315998501)
# NumWebPurchases                              (Income, 0.504874882023529)
# NumCatalogPurchases                  (Spend on Wines, 0.694758477668525)
# NumStorePurchases              (NumCatalogPurchases, 0.5843248825220081)
# NumWebVisitsMonth                     (Total Spend, -0.5136394465211445)
# AcceptedCmp3                         (AcceptedCmp1, 0.08898036235488326)
# AcceptedCmp4                         (AcceptedCmp1, 0.20912977176587982)
# AcceptedCmp5                               (Income, 0.39106590587880136)
# AcceptedCmp1                 (Spend on MeatProducts, 0.3308399733676974)
# Complain                             (Total Spend, -0.03304492696579225)
# Response                              (Total Spend, 0.25067342938287135)
# Years of Higher Education                (Teenhome, 0.11651528029274372)
# Age                                 (Spend on Wines, 0.1703630680787406)
# Numerical_Marital_Status             (AcceptedCmp5, 0.02787900436266781)
# Num_Dependencies                      (Total Spend, -0.5025259851880041)
# Total Spend                                 (Income, 0.8036047706566107)
#
#                                                                       5   \
# Income                           (NumWebVisitsMonth, -0.663073017694985)
# Kidhome                         (NumStorePurchases, -0.5143005101754393)
# Teenhome                   (Spend on FishProducts, -0.20500172836029168)
# Recency                     (Spend on MeatProducts, 0.02633535978017551)
# Spend on Wines               (Spend on MeatProducts, 0.6215812339841893)
# Spend on Fruits                (NumCatalogPurchases, 0.5301832758871711)
# Spend on MeatProducts        (Spend on FishProducts, 0.6106589664768644)
# Spend on FishProducts          (NumCatalogPurchases, 0.5809470000934593)
# Spend on SweetProducts         (NumCatalogPurchases, 0.5458575884634446)
# Spend on GoldProds                 (Spend on Wines, 0.40513070213819724)
# NumDealsPurchases                         (Kidhome, 0.22730861691395582)
# NumWebPurchases               (NumCatalogPurchases, 0.46668887031151157)
# NumCatalogPurchases              (NumStorePurchases, 0.5843248825220081)
# NumStorePurchases                   (NumWebPurchases, 0.556876952381916)
# NumWebVisitsMonth                         (Kidhome, 0.46952584387300894)
# AcceptedCmp3                        (AcceptedCmp4, -0.07364529569950144)
# AcceptedCmp4                               (Income, 0.20713358712670502)
# AcceptedCmp5                          (AcceptedCmp1, 0.3791308827828684)
# AcceptedCmp1                                (Income, 0.3240720867823008)
# Complain                         (Num_Dependencies, 0.03220500611338781)
# Response                    (Spend on MeatProducts, 0.24989683954565975)
# Years of Higher Education     (Spend on GoldProds, -0.11466214321958118)
# Age                               (NumWebPurchases, 0.16241567504797128)
# Numerical_Marital_Status                (Teenhome, 0.027075176337821888)
# Num_Dependencies                 (NumDealsPurchases, 0.4747688769305102)
# Total Spend                      (NumStorePurchases, 0.6887578283222773)
#
#                                                                         6   \
# Income                             (NumStorePurchases, 0.6591315636506273)
# Kidhome                              (Spend on Wines, -0.5018010492487253)
# Teenhome                               (AcceptedCmp5, -0.1866853954837459)
# Recency                     (Spend on SweetProducts, 0.024962303859651952)
# Spend on Wines                       (NumWebPurchases, 0.6046425651180026)
# Spend on Fruits                               (Income, 0.5263400450485617)
# Spend on MeatProducts                (Spend on Fruits, 0.5788076362387176)
# Spend on FishProducts                         (Income, 0.5406215914491233)
# Spend on SweetProducts                        (Income, 0.5378871707271023)
# Spend on GoldProds                  (Spend on Fruits, 0.40239803887190223)
# NumDealsPurchases              (Spend on MeatProducts, -0.200147053096918)
# NumWebPurchases                   (Spend on GoldProds, 0.3987810652086436)
# NumCatalogPurchases            (Spend on FishProducts, 0.5809470000934593)
# NumStorePurchases              (Spend on MeatProducts, 0.5352884205093248)
# NumWebVisitsMonth            (Spend on FishProducts, -0.46860945633638323)
# AcceptedCmp3                      (NumStorePurchases, -0.0728667089874502)
# AcceptedCmp4                        (NumWebPurchases, 0.17137230056143862)
# AcceptedCmp5                     (NumCatalogPurchases, 0.3332613736827275)
# AcceptedCmp1                    (NumCatalogPurchases, 0.31869432975803186)
# Complain                       (Spend on GoldProds, -0.029991743019595573)
# Response                        (NumCatalogPurchases, 0.22521984333432796)
# Years of Higher Education                  (Response, 0.10212926990246228)
# Age                        (Years of Higher Education, 0.1569529863927901)
# Numerical_Marital_Status      (NumCatalogPurchases, -0.025471307661975084)
# Num_Dependencies                (NumCatalogPurchases, -0.4636538286744802)
# Total Spend                    (Spend on FishProducts, 0.6545070546321563)
#
#                                                                       7   \
# Income                       (Spend on FishProducts, 0.5406215914491233)
# Kidhome                         (NumWebVisitsMonth, 0.46952584387300894)
# Teenhome                         (Spend on Fruits, -0.17356648176990352)
# Recency                              (Total Spend, 0.019896516719057625)
# Spend on Wines                            (Kidhome, -0.5018010492487253)
# Spend on Fruits                  (NumStorePurchases, 0.4661778490654676)
# Spend on MeatProducts       (Spend on SweetProducts, 0.5777275796304928)
# Spend on FishProducts          (NumWebVisitsMonth, -0.46860945633638323)
# Spend on SweetProducts           (NumStorePurchases, 0.4651375806966781)
# Spend on GoldProds              (NumStorePurchases, 0.39968960723465635)
# NumDealsPurchases                   (AcceptedCmp5, -0.18859050003456293)
# NumWebPurchases                           (Kidhome, -0.3885434137762578)
# NumCatalogPurchases             (NumWebVisitsMonth, -0.5489379907577792)
# NumStorePurchases                         (Kidhome, -0.5143005101754393)
# NumWebVisitsMonth               (NumStorePurchases, -0.4556937193572155)
# AcceptedCmp3                                 (Age, -0.06261921438435444)
# AcceptedCmp4                     (NumStorePurchases, 0.1597880557808723)
# AcceptedCmp5                              (Response, 0.2960695677965971)
# AcceptedCmp1                 (Spend on FishProducts, 0.2691786523834511)
# Complain                                 (Income, -0.027663827090803166)
# Response                           (Spend on Wines, 0.22418614978695434)
# Years of Higher Education         (NumWebPurchases, 0.09457430502503823)
# Age                           (NumCatalogPurchases, 0.15170348066168698)
# Numerical_Marital_Status        (Spend on Fruits, -0.025443397342686025)
# Num_Dependencies           (Spend on FishProducts, -0.43522363386602875)
# Total Spend                        (Spend on Fruits, 0.6268651768171082)
#
#                                                                       8   \
# Income                      (Spend on SweetProducts, 0.5378871707271023)
# Kidhome                    (Spend on MeatProducts, -0.45750667617221336)
# Teenhome                          (NumWebPurchases, 0.16626694674145467)
# Recency                            (AcceptedCmp1, -0.017363795677822574)
# Spend on Wines                       (AcceptedCmp5, 0.45669398069185374)
# Spend on Fruits                 (NumWebVisitsMonth, -0.4341427390424748)
# Spend on MeatProducts           (NumWebVisitsMonth, -0.5547268550162219)
# Spend on FishProducts           (NumStorePurchases, 0.46030096747022436)
# Spend on SweetProducts          (NumWebVisitsMonth, -0.4417187726819707)
# Spend on GoldProds                 (NumWebPurchases, 0.3987810652086436)
# NumDealsPurchases          (Spend on FishProducts, -0.16329747785175047)
# NumWebPurchases             (Spend on MeatProducts, 0.36759244532121266)
# NumCatalogPurchases         (Spend on SweetProducts, 0.5458575884634446)
# NumStorePurchases                  (Spend on Fruits, 0.4661778490654676)
# NumWebVisitsMonth          (Spend on SweetProducts, -0.4417187726819707)
# AcceptedCmp3                        (AcceptedCmp5, 0.062420766517466454)
# AcceptedCmp4                             (Response, 0.14565996573494383)
# AcceptedCmp5                    (NumWebVisitsMonth, -0.2863239827368995)
# AcceptedCmp1                             (Response, 0.26820739645293046)
# Complain                            (AcceptedCmp4, -0.02560736711771662)
# Response                                  (Recency, -0.2059129430826267)
# Years of Higher Education       (NumStorePurchases, 0.09271501228509843)
# Age                             (NumStorePurchases, 0.14643761023643298)
# Numerical_Marital_Status            (Total Spend, -0.025409553218060363)
# Num_Dependencies                (NumWebVisitsMonth, 0.43217226812866644)
# Total Spend                 (Spend on SweetProducts, 0.6256572064142801)
#
#                                                                        9   \
# Income                              (Spend on Fruits, 0.5263400450485617)
# Kidhome                     (Spend on FishProducts, -0.39706661008014943)
# Teenhome                   (Spend on SweetProducts, -0.16255123179188982)
# Recency                                        (Age, 0.01715143580071399)
# Spend on Wines                 (Spend on FishProducts, 0.409894826644595)
# Spend on Fruits                      (Spend on Wines, 0.4056207233903304)
# Spend on MeatProducts             (NumStorePurchases, 0.5352884205093248)
# Spend on FishProducts           (Spend on GoldProds, 0.43694370056210013)
# Spend on SweetProducts               (Spend on Wines, 0.4098435010062504)
# Spend on GoldProds            (Spend on MeatProducts, 0.3929528419807708)
# NumDealsPurchases          (Spend on SweetProducts, -0.14118836140153337)
# NumWebPurchases             (Spend on SweetProducts, 0.33454661618637993)
# NumCatalogPurchases                        (Kidhome, -0.5347080518370962)
# NumStorePurchases            (Spend on SweetProducts, 0.4651375806966781)
# NumWebVisitsMonth                  (Spend on Fruits, -0.4341427390424748)
# AcceptedCmp3                     (NumWebVisitsMonth, 0.06225155164931434)
# AcceptedCmp4                              (Kidhome, -0.14343120918930347)
# AcceptedCmp5                          (AcceptedCmp4, 0.28115694720522255)
# AcceptedCmp1                (Spend on SweetProducts, 0.24731165024617224)
# Complain                             (AcceptedCmp1, -0.02432894592810204)
# Response                         (Num_Dependencies, -0.15598571155710936)
# Years of Higher Education   (Spend on FishProducts, -0.09145935414531657)
# Age                             (NumWebVisitsMonth, -0.13707235910164245)
# Numerical_Marital_Status   (Spend on FishProducts, -0.022402494753159453)
# Num_Dependencies                   (Spend on Fruits, -0.3988159825050169)
# Total Spend                         (NumWebPurchases, 0.5733454703560453)
#
#                                                                           10  \
# Income                                        (Kidhome, -0.5228484504749652)
# Kidhome                               (NumWebPurchases, -0.3885434137762578)
# Teenhome                                    (Response, -0.15240404123820414)
# Recency                    (Years of Higher Education, -0.016865927501144...
# Spend on Wines                  (Spend on SweetProducts, 0.4098435010062504)
# Spend on Fruits                    (Spend on GoldProds, 0.40239803887190223)
# Spend on MeatProducts                 (Num_Dependencies, -0.520879657224567)
# Spend on FishProducts               (Num_Dependencies, -0.43522363386602875)
# Spend on SweetProducts               (Num_Dependencies, -0.3976097475202579)
# Spend on GoldProds             (Spend on SweetProducts, 0.36710666155431987)
# NumDealsPurchases                     (Spend on Fruits, -0.1379123228349957)
# NumWebPurchases                        (Spend on Fruits, 0.3254418118106341)
# NumCatalogPurchases                    (Spend on Fruits, 0.5301832758871711)
# NumStorePurchases               (Spend on FishProducts, 0.46030096747022436)
# NumWebVisitsMonth                    (Num_Dependencies, 0.43217226812866644)
# AcceptedCmp3                            (Spend on Wines, 0.0597281625161497)
# AcceptedCmp4                      (NumCatalogPurchases, 0.12256471060969672)
# AcceptedCmp5                        (Num_Dependencies, -0.27546134934020045)
# AcceptedCmp1                        (Num_Dependencies, -0.22131510643478602)
# Complain                           (NumWebVisitsMonth, 0.022921827188101415)
# Response                              (NumWebPurchases, 0.15312037700178818)
# Years of Higher Education                 (Total Spend, 0.08939865300819459)
# Age                                       (Total Spend, 0.12425082764023603)
# Numerical_Marital_Status                (AcceptedCmp3, -0.02206987100061402)
# Num_Dependencies               (Spend on SweetProducts, -0.3976097475202579)
# Total Spend                                   (Kidhome, -0.5597274162141495)
#
#                            ...  \
# Income                     ...
# Kidhome                    ...
# Teenhome                   ...
# Recency                    ...
# Spend on Wines             ...
# Spend on Fruits            ...
# Spend on MeatProducts      ...
# Spend on FishProducts      ...
# Spend on SweetProducts     ...
# Spend on GoldProds         ...
# NumDealsPurchases          ...
# NumWebPurchases            ...
# NumCatalogPurchases        ...
# NumStorePurchases          ...
# NumWebVisitsMonth          ...
# AcceptedCmp3               ...
# AcceptedCmp4               ...
# AcceptedCmp5               ...
# AcceptedCmp1               ...
# Complain                   ...
# Response                   ...
# Years of Higher Education  ...
# Age                        ...
# Numerical_Marital_Status   ...
# Num_Dependencies           ...
# Total Spend                ...
#
#                                                                          16  \
# Income                                            (Age, 0.2141987490013356)
# Kidhome                                 (AcceptedCmp5, -0.1938223715481955)
# Teenhome                            (NumStorePurchases, 0.0551684111127188)
# Recency                                     (Kidhome, 0.012434005438442511)
# Spend on Wines                            (AcceptedCmp4, 0.334021794461375)
# Spend on Fruits                            (Teenhome, -0.17356648176990352)
# Spend on MeatProducts                      (Teenhome, -0.26288400669640993)
# Spend on FishProducts                   (AcceptedCmp5, 0.20009051619078005)
# Spend on SweetProducts                     (Teenhome, -0.16255123179188982)
# Spend on GoldProds                            (Response, 0.133322198453978)
# NumDealsPurchases                   (NumStorePurchases, 0.0847052434603589)
# NumWebPurchases                                  (Age, 0.16241567504797128)
# NumCatalogPurchases                         (Response, 0.22521984333432796)
# NumStorePurchases                        (AcceptedCmp4, 0.1597880557808723)
# NumWebVisitsMonth                               (Age, -0.13707235910164245)
# AcceptedCmp3               (Numerical_Marital_Status, -0.02206987100061402)
# AcceptedCmp4                                (Teenhome, 0.04916013440528621)
# AcceptedCmp5                      (NumDealsPurchases, -0.18859050003456293)
# AcceptedCmp1                        (NumStorePurchases, 0.1703255201219424)
# Complain                         (NumStorePurchases, -0.011779845862540576)
# Response                             (Spend on Fruits, 0.12188149881359446)
# Years of Higher Education           (Num_Dependencies, 0.04927077289277749)
# Age                            (Spend on MeatProducts, 0.05326639684893009)
# Numerical_Marital_Status     (Spend on SweetProducts, -0.01102621909390096)
# Num_Dependencies                       (AcceptedCmp1, -0.22131510643478602)
# Total Spend                                 (Response, 0.25067342938287135)
#
#                                                                       17  \
# Income                               (AcceptedCmp4, 0.20713358712670502)
# Kidhome                              (AcceptedCmp1, -0.1652393665110356)
# Teenhome                             (AcceptedCmp4, 0.04916013440528621)
# Recency                                  (Teenhome, 0.01008480002221794)
# Spend on Wines                           (Response, 0.22418614978695434)
# Spend on Fruits                 (NumDealsPurchases, -0.1379123228349957)
# Spend on MeatProducts                    (Response, 0.24989683954565975)
# Spend on FishProducts          (NumDealsPurchases, -0.16329747785175047)
# Spend on SweetProducts         (NumDealsPurchases, -0.14118836140153337)
# Spend on GoldProds                    (AcceptedCmp3, 0.1265155713027966)
# NumDealsPurchases              (Spend on GoldProds, 0.06791926609113429)
# NumWebPurchases                 (Num_Dependencies, -0.15898688643041803)
# NumCatalogPurchases                           (Age, 0.15170348066168698)
# NumStorePurchases                             (Age, 0.14643761023643298)
# NumWebVisitsMonth                        (Teenhome, 0.12904487521729432)
# AcceptedCmp3                              (Income, -0.01809316876157871)
# AcceptedCmp4                   (NumDealsPurchases, 0.040021573329507495)
# AcceptedCmp5                             (Teenhome, -0.1866853954837459)
# AcceptedCmp1                              (Kidhome, -0.1652393665110356)
# Complain                             (AcceptedCmp3, 0.01061491897541824)
# Response                   (Spend on SweetProducts, 0.11446318580005402)
# Years of Higher Education                 (Kidhome, -0.0492622696123759)
# Age                          (Spend on FishProducts, 0.0432022735461907)
# Numerical_Marital_Status           (NumWebPurchases, 0.0106851664849554)
# Num_Dependencies                 (NumWebPurchases, -0.15898688643041803)
# Total Spend                          (AcceptedCmp4, 0.22353767386182957)
#
#                                                                           18  \
# Income                       (Years of Higher Education, 0.1599403808327332)
# Kidhome                                 (AcceptedCmp4, -0.14343120918930347)
# Teenhome                                       (Income, 0.04879145589676085)
# Recency                       (Spend on FishProducts, -0.007058571615442959)
# Spend on Wines              (Years of Higher Education, 0.19840546012563648)
# Spend on Fruits                              (Response, 0.12188149881359446)
# Spend on MeatProducts                (NumDealsPurchases, -0.200147053096918)
# Spend on FishProducts                        (Response, 0.10907468492831522)
# Spend on SweetProducts                       (Response, 0.11446318580005402)
# Spend on GoldProds         (Years of Higher Education, -0.11466214321958118)
# NumDealsPurchases                       (AcceptedCmp4, 0.040021573329507495)
# NumWebPurchases                              (Response, 0.15312037700178818)
# NumCatalogPurchases                      (AcceptedCmp4, 0.12256471060969672)
# NumStorePurchases           (Years of Higher Education, 0.09271501228509843)
# NumWebVisitsMonth                        (AcceptedCmp3, 0.06225155164931434)
# AcceptedCmp3                                 (Kidhome, 0.016148171026989868)
# AcceptedCmp4                       (NumWebVisitsMonth, -0.03181805235130089)
# AcceptedCmp5                       (Spend on GoldProds, 0.16922430293771012)
# AcceptedCmp1                                (Teenhome, -0.14056513813280894)
# Complain                                    (Teenhome, 0.008026011399171825)
# Response                        (Spend on FishProducts, 0.10907468492831522)
# Years of Higher Education                  (Complain, -0.036937311893614176)
# Age                                         (Response, -0.02438468726849895)
# Numerical_Marital_Status                     (Income, -0.007210343727599278)
# Num_Dependencies                            (Response, -0.15598571155710936)
# Total Spend                                 (Teenhome, -0.13641755213609302)
#
#                                                                           19  \
# Income                                        (Response, 0.1503967270383608)
# Kidhome                                     (Response, -0.06261308461192004)
# Teenhome                               (AcceptedCmp3, -0.047013356575430494)
# Recency                             (Spend on Fruits, -0.005875981744683821)
# Spend on Wines                                     (Age, 0.1703630680787406)
# Spend on Fruits            (Years of Higher Education, -0.07751079004989427)
# Spend on MeatProducts                    (AcceptedCmp4, 0.09839201140937717)
# Spend on FishProducts      (Years of Higher Education, -0.09145935414531657)
# Spend on SweetProducts     (Years of Higher Education, -0.08382401150638724)
# Spend on GoldProds                  (NumDealsPurchases, 0.06791926609113429)
# NumDealsPurchases          (Years of Higher Education, 0.028269027877102174)
# NumWebPurchases                          (AcceptedCmp5, 0.14750729558304793)
# NumCatalogPurchases                      (AcceptedCmp3, 0.12042835576530896)
# NumStorePurchases                    (NumDealsPurchases, 0.0847052434603589)
# NumWebVisitsMonth          (Years of Higher Education, -0.053132609730806...
# AcceptedCmp3                         (Spend on Fruits, 0.015774445468131167)
# AcceptedCmp4                                (Complain, -0.02560736711771662)
# AcceptedCmp5                          (NumWebPurchases, 0.14750729558304793)
# AcceptedCmp1                       (NumDealsPurchases, -0.12539191778908018)
# Complain                           (NumDealsPurchases, 0.007344867372026713)
# Response                    (Years of Higher Education, 0.10212926990246228)
# Years of Higher Education          (NumDealsPurchases, 0.028269027877102174)
# Age                                    (AcceptedCmp5, -0.017949662871405515)
# Numerical_Marital_Status               (AcceptedCmp4, -0.005909994320211462)
# Num_Dependencies                                  (Age, 0.08774501476940401)
# Total Spend                                       (Age, 0.12425082764023603)
#
#                                                                           20  \
# Income                              (NumDealsPurchases, -0.1275970596460106)
# Kidhome                     (Years of Higher Education, -0.0492622696123759)
# Teenhome                                      (Kidhome, -0.0461372451206927)
# Recency                                     (Complain, 0.005735242102007039)
# Spend on Wines                            (AcceptedCmp3, 0.0597281625161497)
# Spend on Fruits            (Numerical_Marital_Status, -0.025443397342686025)
# Spend on MeatProducts                             (Age, 0.05326639684893009)
# Spend on FishProducts                              (Age, 0.0432022735461907)
# Spend on SweetProducts                       (Recency, 0.024962303859651952)
# Spend on GoldProds                                (Age, 0.06182887946506069)
# NumDealsPurchases                           (Response, 0.025739323504496422)
# NumWebPurchases             (Years of Higher Education, 0.09457430502503823)
# NumCatalogPurchases                         (Teenhome, -0.10776339654966252)
# NumStorePurchases                        (AcceptedCmp3, -0.0728667089874502)
# NumWebVisitsMonth                       (AcceptedCmp4, -0.03181805235130089)
# AcceptedCmp3                   (Spend on MeatProducts, 0.012687269380977246)
# AcceptedCmp4                  (Spend on SweetProducts, 0.023401867271415404)
# AcceptedCmp5                            (AcceptedCmp3, 0.062420766517466454)
# AcceptedCmp1                             (AcceptedCmp3, 0.08898036235488326)
# Complain                              (AcceptedCmp5, -0.0064230849630290045)
# Response                                     (Kidhome, -0.06261308461192004)
# Years of Higher Education        (Spend on MeatProducts, 0.0260769016222163)
# Age                                           (Recency, 0.01715143580071399)
# Numerical_Marital_Status                         (Age, 0.004848242894921509)
# Num_Dependencies                        (AcceptedCmp4, -0.06757832404062757)
# Total Spend                 (Years of Higher Education, 0.08939865300819459)
#
#                                                                           21  \
# Income                                       (Teenhome, 0.04879145589676085)
# Kidhome                                      (Teenhome, -0.0461372451206927)
# Teenhome                          (Spend on GoldProds, -0.03030921672478026)
# Recency                          (NumStorePurchases, -0.0032631692153803813)
# Spend on Wines                             (Complain, -0.035677648585537215)
# Spend on Fruits                                  (Age, 0.016299860499078188)
# Spend on MeatProducts      (Numerical_Marital_Status, -0.036125996906753575)
# Spend on FishProducts      (Numerical_Marital_Status, -0.022402494753159453)
# Spend on SweetProducts                  (AcceptedCmp4, 0.023401867271415404)
# Spend on GoldProds                          (Teenhome, -0.03030921672478026)
# NumDealsPurchases                      (Spend on Wines, 0.02336050708865761)
# NumWebPurchases                         (AcceptedCmp3, 0.053112879377767194)
# NumCatalogPurchases                (NumDealsPurchases, -0.08647907138590792)
# NumStorePurchases                             (Teenhome, 0.0551684111127188)
# NumWebVisitsMonth                           (Recency, -0.028191053540690594)
# AcceptedCmp3                                 (Complain, 0.01061491897541824)
# AcceptedCmp4                                 (Recency, 0.014345994474641214)
# AcceptedCmp5                 (Numerical_Marital_Status, 0.02787900436266781)
# AcceptedCmp1                                (Complain, -0.02432894592810204)
# Complain                                     (Recency, 0.005735242102007039)
# Response                           (NumDealsPurchases, 0.025739323504496422)
# Years of Higher Education               (AcceptedCmp5, 0.024764427990261104)
# Age                                  (Spend on Fruits, 0.016299860499078188)
# Numerical_Marital_Status   (Years of Higher Education, -0.004427444684083...
# Num_Dependencies            (Years of Higher Education, 0.04927077289277749)
# Total Spend                        (NumDealsPurchases, -0.08728710880458672)
#
#                                                                           22  \
# Income                                     (Complain, -0.027663827090803166)
# Kidhome                                      (Complain, 0.03659426552760407)
# Teenhome                    (Numerical_Marital_Status, 0.027075176337821888)
# Recency                           (NumDealsPurchases, -0.001614337550674651)
# Spend on Wines                      (NumDealsPurchases, 0.02336050708865761)
# Spend on Fruits                         (AcceptedCmp3, 0.015774445468131167)
# Spend on MeatProducts                         (Recency, 0.02633535978017551)
# Spend on FishProducts                      (Complain, -0.019421587713681857)
# Spend on SweetProducts                     (Complain, -0.020616392451293163)
# Spend on GoldProds                         (Complain, -0.029991743019595573)
# NumDealsPurchases            (Numerical_Marital_Status, 0.01391004101620991)
# NumWebPurchases                    (NumWebVisitsMonth, -0.02477697013190806)
# NumCatalogPurchases         (Years of Higher Education, 0.08061158894511251)
# NumStorePurchases                           (Response, 0.019998027629527567)
# NumWebVisitsMonth                    (NumWebPurchases, -0.02477697013190806)
# AcceptedCmp3                      (NumDealsPurchases, -0.010324717546571197)
# AcceptedCmp4                      (Spend on GoldProds, 0.013426027157716727)
# AcceptedCmp5               (Years of Higher Education, 0.024764427990261104)
# AcceptedCmp1                                (Recency, -0.017363795677822574)
# Complain                                         (Age, 0.004829048791695764)
# Response                                         (Age, -0.02438468726849895)
# Years of Higher Education                   (Recency, -0.016865927501144524)
# Age                                     (AcceptedCmp1, 0.015114627627363068)
# Numerical_Marital_Status            (NumStorePurchases, 0.00281192547390667)
# Num_Dependencies            (Numerical_Marital_Status, 0.035318837883867034)
# Total Spend                              (AcceptedCmp3, 0.05007161878821712)
#
#                                                                           23  \
# Income                                  (AcceptedCmp3, -0.01809316876157871)
# Kidhome                      (Numerical_Marital_Status, 0.02168192653049881)
# Teenhome                                      (Recency, 0.01008480002221794)
# Recency                               (AcceptedCmp5, -0.0011090343153192764)
# Spend on Wines                               (Recency, 0.015512046880996918)
# Spend on Fruits                         (AcceptedCmp4, 0.008440303292359556)
# Spend on MeatProducts        (Years of Higher Education, 0.0260769016222163)
# Spend on FishProducts                   (AcceptedCmp4, 0.011838042050493937)
# Spend on SweetProducts                           (Age, 0.015033010460559052)
# Spend on GoldProds         (Numerical_Marital_Status, -0.021234904986700873)
# NumDealsPurchases                      (AcceptedCmp3, -0.010324717546571197)
# NumWebPurchases                            (Complain, -0.013088341895069923)
# NumCatalogPurchases                          (Recency, 0.027549048547353003)
# NumStorePurchases                          (Complain, -0.011779845862540576)
# NumWebVisitsMonth                           (Complain, 0.022921827188101415)
# AcceptedCmp3                 (Spend on SweetProducts, 0.0070083980885639165)
# AcceptedCmp4                   (Spend on FishProducts, 0.011838042050493937)
# AcceptedCmp5                                    (Age, -0.017949662871405515)
# AcceptedCmp1                                     (Age, 0.015114627627363068)
# Complain                            (Spend on Fruits, -0.003473896540652495)
# Response                           (NumStorePurchases, 0.019998027629527567)
# Years of Higher Education  (Numerical_Marital_Status, -0.004427444684083072)
# Age                           (Spend on SweetProducts, 0.015033010460559052)
# Numerical_Marital_Status          (NumWebVisitsMonth, 0.0014072780357823106)
# Num_Dependencies                             (Complain, 0.03220500611338781)
# Total Spend                                 (Complain, -0.03304492696579225)
#
#                                                                           24  \
# Income                                       (Recency, 0.012500881075176665)
# Kidhome                                 (AcceptedCmp3, 0.016148171026989868)
# Teenhome                                    (Complain, 0.008026011399171825)
# Recency                    (Numerical_Marital_Status, -0.0009006291871613...
# Spend on Wines              (Numerical_Marital_Status, -0.01104061142423984)
# Spend on Fruits                             (Recency, -0.005875981744683821)
# Spend on MeatProducts                       (Complain, -0.02064641861827877)
# Spend on FishProducts                       (Recency, -0.007058571615442959)
# Spend on SweetProducts      (Numerical_Marital_Status, -0.01102621909390096)
# Spend on GoldProds                           (Recency, 0.014269686647998487)
# NumDealsPurchases                           (Complain, 0.007344867372026713)
# NumWebPurchases               (Numerical_Marital_Status, 0.0106851664849554)
# NumCatalogPurchases        (Numerical_Marital_Status, -0.025471307661975084)
# NumStorePurchases                          (Recency, -0.0032631692153803813)
# NumWebVisitsMonth                           (Response, 0.005228883476472238)
# AcceptedCmp3                  (Spend on FishProducts, 0.0033150789782824238)
# AcceptedCmp4                         (Spend on Fruits, 0.008440303292359556)
# AcceptedCmp5                              (Complain, -0.0064230849630290045)
# AcceptedCmp1                (Numerical_Marital_Status, 0.011675246576252386)
# Complain                                    (Response, 0.001453621594284556)
# Response                           (NumWebVisitsMonth, 0.005228883476472238)
# Years of Higher Education              (AcceptedCmp3, 0.0026953660740060966)
# Age                         (Numerical_Marital_Status, 0.004848242894921509)
# Numerical_Marital_Status                   (Complain, 0.0011150061448652506)
# Num_Dependencies                       (AcceptedCmp3, -0.022567202245360532)
# Total Spend                (Numerical_Marital_Status, -0.025409553218060363)
#
#                                                                           25
# Income                     (Numerical_Marital_Status, -0.007210343727599278)
# Kidhome                                      (Recency, 0.012434005438442511)
# Teenhome                              (Spend on Wines, 0.004328835595117334)
# Recency                             (NumWebPurchases, 0.0006591556790231541)
# Spend on Wines                              (Teenhome, 0.004328835595117334)
# Spend on Fruits                            (Complain, -0.003473896540652495)
# Spend on MeatProducts                   (AcceptedCmp3, 0.012687269380977246)
# Spend on FishProducts                  (AcceptedCmp3, 0.0033150789782824238)
# Spend on SweetProducts                 (AcceptedCmp3, 0.0070083980885639165)
# Spend on GoldProds                      (AcceptedCmp4, 0.013426027157716727)
# NumDealsPurchases                           (Recency, -0.001614337550674651)
# NumWebPurchases                             (Recency, 0.0006591556790231541)
# NumCatalogPurchases                        (Complain, -0.017734821835252792)
# NumStorePurchases            (Numerical_Marital_Status, 0.00281192547390667)
# NumWebVisitsMonth          (Numerical_Marital_Status, 0.0014072780357823106)
# AcceptedCmp3               (Years of Higher Education, 0.0026953660740060...
# AcceptedCmp4               (Numerical_Marital_Status, -0.005909994320211462)
# AcceptedCmp5                               (Recency, -0.0011090343153192764)
# AcceptedCmp1               (Years of Higher Education, 0.0020058111463604...
# Complain                   (Numerical_Marital_Status, 0.0011150061448652506)
# Response                                    (Complain, 0.001453621594284556)
# Years of Higher Education              (AcceptedCmp1, 0.0020058111463604603)
# Age                                         (Complain, 0.004829048791695764)
# Numerical_Marital_Status                   (Recency, -0.0009006291871613497)
# Num_Dependencies                             (Recency, 0.016295320928216173)
# Total Spend                                  (Recency, 0.019896516719057625)
#
# [26 rows x 25 columns]

# %% [markdown]
#     As we can see, the most correlated feature pairs are expected (i.e. income is positively correlated with total spend etc)
#
#     However there are a few unexpected correlations like positive correlation between consumption of wine and education, and negative correlation between the number of dependencies and total spend

# %%
# Create boxplots to investigate the correlation between education and consumption of wine
fig, ax =plt.subplots()
fig.set_size_inches(8,8)
sns.boxplot(x="Years of Higher Education", y="Spend on Wines",data=df,ax=ax)

fig, ax =plt.subplots()
fig.set_size_inches(12,12)
Age_group=df["Age"].apply( lambda x:f"{x//10*10}$\leq$age<{x//10*10+10}" )
sns.boxplot(x="Years of Higher Education", y="Spend on Wines",data=df.loc[ df["Age"] < 70 ] ,hue=Age_group,ax=ax)
# Out:
# <AxesSubplot:xlabel='Years of Higher Education', ylabel='Spend on Wines'>

# %% [markdown]
#     To investigate the correlation between consumption of wines and education, I created a nested boxplot accross different age group. As we can see, the correlation persists across all age groups. This excludes the possibility that the correlation is caused by age while age being slightly correlated with education.

# %%
fig, ax =plt.subplots(1,2)
fig.set_size_inches(16,8)
sns.boxplot(y="Total Spend", x="Num_Dependencies",data=df,ax=ax[0])
sns.boxplot(y="Income", x="Num_Dependencies",data=df,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Num_Dependencies', ylabel='Income'>

# %% [markdown]
#     As we can see above, number of dependencies is both negatively correlated with Income and Spend. It is likely that the negative correlation we see between number of dependencies and total spend is caused by the negative correlation between number of dependencies and income which in turn might be caused by education. The key point is that while family with more dependencies is most certainly going to spend more,

# %% [markdown]
# ## Principal Component Analysis

# %%
# Define a charcterstics dataframe for segmentation
char_df=df.copy()
char = ["Income","Years of Higher Education","Age","Num_Dependencies","Kidhome","Teenhome"]
char_df = char_df[char]

# Rescale each feature to have variance 1 for better PCA result
Scaler = StandardScaler()
Scaler.fit(char_df)
scaled_df = pd.DataFrame( Scaler.transform(char_df),columns=char_df.columns )
print("Features sucesfully scaled")
# Out:
# Features sucesfully scaled

# %%
# Apply PCA to reduce the dimension of data for Clustering
pca = PCA(n_components=3)
pca.fit(scaled_df)
PCs = pd.DataFrame(pca.components_,columns=char_df.columns)
PCA_df = pd.DataFrame(pca.transform(scaled_df),columns=["1th PC","2th PC","3th PC"])

# %%
# Print out principal components and eigenvalues
components = pd.DataFrame(pca.components_,columns = scaled_df.columns,index=["1th PC","2th PC","3th PC"])
components["Eigenvalue"] = pca.explained_variance_
components.T
# Out:
#                              1th PC    2th PC    3th PC
# Income                    -0.433423  0.338572 -0.017291
# Years of Higher Education -0.032867  0.315936 -0.931732
# Age                       -0.057197  0.563015  0.186502
# Num_Dependencies           0.629957  0.240981  0.022961
# Kidhome                    0.560857 -0.257783 -0.204094
# Teenhome                   0.310463  0.586553  0.233693
# Eigenvalue                 2.178968  1.746000  0.930753

# %% [markdown]
# ## KMeans Clustering

# %%
# Apply elbow method
from sklearn.cluster import KMeans
sse = {}
for k in range(1,8):
    KM = KMeans(n_clusters=k,max_iter=1000).fit(PCA_df)
    sse[k]=KM.inertia_
    
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot()
ax.plot( list(sse.keys()), list(sse.values()) )
ax.set_xlabel("Number of Clusters")
ax.set_ylabel("Square Lost")
ax.set_title("Square Lost over Number of Clusters")
# Out:
# Text(0.5, 1.0, 'Square Lost over Number of Clusters')

# %% [markdown]
#     According to the elbow method, 4 is the optimal number of clusters

# %%
## Apply KMeans with 4 clusters
KM = KMeans(n_clusters=4)
# fit model and predict clusters
clusters = KM.fit_predict(PCA_df)
PCA_df["Clusters"] = clusters
# Add the Clusters feature to the orignal dataframe.
df["Clusters"]= clusters

# %%
# Scatter plots of clusters in the reduced space
x=PCA_df["1th PC"]
y=PCA_df["2th PC"]
z=PCA_df["3th PC"]

fig = plt.figure(figsize=(15,15))
ax = plt.subplot( projection='3d')
ax.set_xlabel(x.name)
ax.set_ylabel(y.name)
ax.set_zlabel(z.name)
ax.scatter(x, y, z, s=40, c=PCA_df["Clusters"])
ax.set_title("Clusters in Principal Space")
plt.show()

# %%
# Show the counts of each cluster
df["Clusters"].value_counts()
# Out:
# 2    630
# 3    569
# 1    551
# 0    413
# Name: Clusters, dtype: int64

# %% [markdown]
# ## Customer Segmentation

# %%
# Explore the charctersitcs of the different groups
i=0
for col in char:
    if i%3==0:
        fig, ax = plt.subplots(1,3)
        fig.set_size_inches(25,8)
    sns.kdeplot(data=df, x=col, hue="Clusters", fill=True,ax=ax[i%3])
    ax[i%3].set_title(col)
    i+=1
# Out:
# /Users/zhongyuanchen/opt/anaconda3/envs/Py/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
# Explore buying behavior of different groups
behavior = ['Total Spend','NumDealsPurchases', 'NumWebVisitsMonth',
       'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
       'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
       'AcceptedCmp1', 'Complain', 'Response',]
i=0
for col in behavior:
    if i%3==0:
        fig, ax = plt.subplots(1,3)
        fig.set_size_inches(25,8)
    sns.kdeplot(data=df, x=col, hue="Clusters", fill=True,ax=ax[i%3])
    ax[i%3].set_title(col)
    i+=1

# %% [markdown]
#     We now make infference from the above plots
#
# ## Group 0
#     Characteristics:
#
#         Mid high income (around 60k)
#
#         Have one teenager as dependency
#
#         Older
#
#     Buying Behavior:
#
#         Average spend
#
#         Many website purchases
#
#
# ## Group 1
#
#     Characteristics:
#
#         Low income (around 35k)
#
#         Have one kid as dependency
#
#         Younger
#
#     Buying Behavior:
#
#         Low spend
#
#         Many website visits
#
#         Few website purchases
#
#         Least likely to respond
#
#         More store purchases
#
#
# ## Group 2
#
#     Characteristics:
#
#         High income (around 80k)
#
#         Have no dependency
#
#         Higher spend
#
#     Buying Behavior:
#
#         Very few deal purchases
#
#         Very few website visits
#
#         More website purchases
#
#         Many catelog Purchases
#
#         Most likely to respond
#
#
# ## Group 3
#     Characteristics:
#
#         Mid low income (around 45k)
#
#         Have 2 to 3 dependencies
#
#         Middle age
#
#     Buying Behavior:
#
#         Low spend
#
#         Many website visits
#
#         Few website purchases
#
#         More Store purchases

# %% [markdown]
# ## Conclusion
#
#     Knowing the positive correlation between education and wine consumption, sending wine product promotion to the highly educated customers might boost sales
#
#     Group 0 (mid high income) and group 2 (high income) should be the target groups for online advertisement as they have low number of website visits but have high number of website purchases
#
#     Group 1 (low income) and group 3 (mid low income) despite having higher number of website vistis, they make their purchases mostly in store. Targeting this group with promotions of products that are only avalible in store such as food might attract customers and boost sales.
